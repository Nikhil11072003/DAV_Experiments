# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil11072003/DAV_Experiments/blob/main/DAV_Exp_4%2C5%266.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import adfuller

# %%
import pandas as pd
df = pd.read_csv("stock_data.csv",
                 parse_dates=True,
                 index_col="Date")

# %%
df.head()
# Out:
#             Unnamed: 0   Open   High    Low  Close    Volume  Name
# Date
# 2006-01-03         NaN  39.69  41.22  38.79  40.91  24232729  AABA
# 2006-01-04         NaN  41.22  41.90  40.77  40.97  20553479  AABA
# 2006-01-05         NaN  40.93  41.73  40.85  41.53  12829610  AABA
# 2006-01-06         NaN  42.88  43.57  42.80  43.21  29422828  AABA
# 2006-01-09         NaN  43.10  43.66  42.82  43.42  16268338  AABA

# %% [markdown]
# We will drop columns from the dataset that are not important for our visualization.

# %%
# deleting column
df.drop(columns='Unnamed: 0', inplace =True)
df.head()
# Out:
#              Open   High    Low  Close    Volume  Name
# Date
# 2006-01-03  39.69  41.22  38.79  40.91  24232729  AABA
# 2006-01-04  41.22  41.90  40.77  40.97  20553479  AABA
# 2006-01-05  40.93  41.73  40.85  41.53  12829610  AABA
# 2006-01-06  42.88  43.57  42.80  43.21  29422828  AABA
# 2006-01-09  43.10  43.66  42.82  43.42  16268338  AABA

# %%
# @title Low

from matplotlib import pyplot as plt
df['Low'].plot(kind='line', figsize=(8, 4), title='Low')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# Plotting Line plot for Time Series data

# %% [markdown]
# High vs Date

# %%
# Assuming df is your DataFrame
sns.set(style="whitegrid")  # Setting the style to whitegrid for a clean background

plt.figure(figsize=(12, 6))  # Setting the figure size
sns.lineplot(data=df, x='Date', y='High', label='High Price', color='blue')

# Adding labels and title
plt.xlabel('Date')
plt.ylabel('High')
plt.title('Share Highest Price Over Time')

plt.show()

# %% [markdown]
# Low vs date

# %%
from matplotlib import pyplot as plt
df['Low'].plot(kind='line', figsize=(10, 8), title='Low')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# Resampling
#
#  resampling the data on a monthly basis can provide a clearer view of trends and patterns, especially when we are dealing with daily data. Using mean

# %%
# Assuming df is your DataFrame with a datetime index
df_resampled = df.resample('M').mean() # Resampling to monthly frequency, using mean as an aggregation function

sns.set(style="whitegrid") # Setting the style to whitegrid for a clean background

# Plotting the 'high' column with seaborn, setting x as the resampled 'Date'
plt.figure(figsize=(12, 6)) # Setting the figure size
sns.lineplot(data=df_resampled, x=df_resampled.index, y='High', label='Month Wise Average High Price', color='blue')

# Adding labels and title
plt.xlabel('Date (Monthly)')
plt.ylabel('High')
plt.title('Monthly Resampling Highest Price Over Time')

plt.show()
# Out:
# <ipython-input-9-e449d1619fa3>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_resampled = df.resample('M').mean() # Resampling to monthly frequency, using mean as an aggregation function

# %% [markdown]
# **ACF**
#
# Detecting Seasonality Using Auto Correlation

# %%
#df.set_index('date', inplace=True)

# Plot the ACF
plt.figure(figsize=(12, 6))
plot_acf(df['Volume'], lags=40)
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.title('Autocorrelation Function (ACF) Plot')
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

# Assuming df is your DataFrame
result = adfuller(df['High'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:', result[4])
# Out:
# ADF Statistic: 0.7671404880535936
# p-value: 0.9910868050318213
# Critical Values: {'1%': -3.4325316347197403, '5%': -2.862503905260741, '10%': -2.5672831121111113}

# %% [markdown]
# Smoothening the data using Differencing and Moving Average
# Differencing involves subtracting the previous observation from the current observation to remove trends or seasonality.

# %%
# Differencing
df['high_diff'] = df['High'].diff()

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(df['High'], label='Original High', color='blue')
plt.plot(df['high_diff'], label='Differenced High', linestyle='--', color='green')
plt.legend()
plt.title('Original vs Differenced High')
plt.show()

# %%
# Moving Average
window_size = 120
df['high_smoothed'] = df['High'].rolling(window=window_size).mean()

# Plotting
plt.figure(figsize=(12, 6))

plt.plot(df['High'], label='Original High', color='blue')
plt.plot(df['high_smoothed'], label=f'Moving Average (Window={window_size})', linestyle='--', color='orange')

plt.xlabel('Date')
plt.ylabel('High')
plt.title('Original vs Moving Average')
plt.legend()
plt.show()

# %% [markdown]
# **PACF**

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_pacf

# Plot the PACF
plt.figure(figsize=(12, 6))
plot_pacf(df['Volume'], lags=40)  # You can adjust the number of lags as needed
plt.xlabel('Lag')
plt.ylabel('Partial Autocorrelation')
plt.title('Partial Autocorrelation Function (PACF) Plot')
plt.show()

# %% [markdown]
# **ARIMA Model**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA

# %%
print(df.isnull().sum())
# Out:
# Open               0
# High               0
# Low                0
# Close              0
# Volume             0
# Name               0
# high_diff          1
# high_smoothed    119
# dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3019 entries, 2006-01-03 to 2017-12-29
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Open           3019 non-null   float64
#  1   High           3019 non-null   float64
#  2   Low            3019 non-null   float64
#  3   Close          3019 non-null   float64
#  4   Volume         3019 non-null   int64
#  5   Name           3019 non-null   object
#  6   high_diff      3018 non-null   float64
#  7   high_smoothed  2900 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 212.3+ KB
# None

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Close'], label='Close Price')
plt.title('Close Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %%
# Stationarity check
result = adfuller(df['Close'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])
# Out:
# ADF Statistic: 0.9478981895596861
# p-value: 0.9936846299287978

# %%
# Apply differencing
df['Close_diff'] = df['Close'].diff().dropna()

# %%
# Apply differencing and drop NaN values
df['Close_diff'] = df['Close'].diff()
df.dropna(subset=['Close_diff'], inplace=True)

# %%
# Stationarity check after differencing
result_diff = adfuller(df['Close_diff'])
print('ADF Statistic after differencing:', result_diff[0])
print('p-value after differencing:', result_diff[1])
# Out:
# ADF Statistic after differencing: -12.44756532607074
# p-value after differencing: 3.6357795917205046e-23

# %%
# ACF and PACF plots after differencing
plt.figure(figsize=(12, 6))
plot_acf(df['Close_diff'], lags=40, title='ACF Plot after Differencing')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plot_pacf(df['Close_diff'], lags=40, title='PACF Plot after Differencing')
plt.xlabel('Lag')
plt.ylabel('Partial Autocorrelation')
plt.show()

# %%
# Model fitting
model = ARIMA(df['Close_diff'], order=(p, d, q))
results = model.fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-6cbdb09142b0> in <cell line: 2>()
#       1 # Model fitting
# ----> 2 model = ARIMA(df['Close_diff'], order=(p, d, q))
#       3 results = model.fit()
#
# NameError: name 'p' is not defined
